# %% [markdown]
# ## PROBLEM 3 : Implement PCA on MNIST

# %%
# Importing the required libraries

import scipy
import numpy as np
# import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score
# from sklearn.preprocessing import StandardScaler

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

from mnist_parser import MNISTDataParsers
from pca import PCAWithEigenDecomposition

# %%
# Configuring libraries

seed = 42
np.random.seed(seed=seed)

# %% [markdown]
# ### PCA with Eigen Decomposition

# %%
data_parser = MNISTDataParser()
X_train, y_train, X_test, y_test = data_parser.parse_data(verbose=0, sample_data=False)

print(f"Shape of Training Data = {X_train.shape}")
print(f"Shape of Training Labels = {y_train.shape}")

print(f"Shape of Testing Data = {X_test.shape}")
print(f"Shape of Testing Labels = {y_test.shape}")
# Out:
# Shape of Training Data = (60000, 784)
# Shape of Training Labels = (60000,)
# Shape of Testing Data = (10000, 784)
# Shape of Testing Labels = (10000,)

# %% [markdown]
# #### 1. PCA with 5 Principal Components

# %%
pca = PCAWithEigenDecomposition(n_components=5)

X_train_proj = pca.fit_transform(X_train)
X_test_proj = pca.transform(X_test)

# %%
print(f"Explained Variance Ratio: {pca.explained_variance_ratio}")
# Out:
# Explained Variance Ratio: [0.09704664 0.07095924 0.06169089 0.05389419 0.04868797]

# %%
print(f"Shape of Projected Training Data = {X_train_proj.shape}")
# Out:
# Shape of Projected Training Data = (60000, 5)

# %% [markdown]
# #### A. Logistic Regression

# %%
lr = LogisticRegression(random_state=seed)
lr.fit(X_train_proj, y_train)
# Out:
# /home/kishore/Documents/Northeastern Coursework/USML/Code_Files/env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
y_train_pred = lr.predict(X_train_proj)

training_acc = accuracy_score(y_train, y_train_pred) * 100

print(f"Training Accuracy: {training_acc:.2f}%")
# Out:
# Training Accuracy: 67.14%

# %%
y_test_pred = lr.predict(X_test_proj)

testing_acc = accuracy_score(y_test, y_test_pred) * 100

print(f"Testing Accuracy: {testing_acc:.2f}%")
# Out:
# Testing Accuracy: 68.63%

# %% [markdown]
# #### B. Decision Tree Classifier

# %%
clf = DecisionTreeClassifier(random_state=seed)
clf.fit(X_train_proj, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_train_pred = clf.predict(X_train_proj)

training_acc = accuracy_score(y_train, y_train_pred) * 100

print(f"Training Accuracy: {training_acc:.2f}%")
# Out:
# Training Accuracy: 100.00%

# %%
y_test_pred = clf.predict(X_test_proj)

testing_acc = accuracy_score(y_test, y_test_pred) * 100

print(f"Testing Accuracy: {testing_acc:.2f}%")
# Out:
# Testing Accuracy: 67.04%

# %% [markdown]
# ### 2. PCA with 20 Principal Components

# %%
pca = PCAWithEigenDecomposition(n_components=20)

X_train_proj = pca.fit_transform(X_train)
X_test_proj = pca.transform(X_test)

# %%
print("Explained Variance Ratio:")
print(pca.explained_variance_ratio)
# Out:
# Explained Variance Ratio:
# [0.09704664 0.07095924 0.06169089 0.05389419 0.04868797 0.04312231
#  0.0327193  0.02883895 0.02762029 0.02357001 0.0210919  0.02022991
#  0.01715818 0.01692111 0.01578641 0.01482953 0.01324561 0.01276897
#  0.01187263 0.01152684]

# %%
print(f"Shape of Projected Training Data = {X_train_proj.shape}")
# Out:
# Shape of Projected Training Data = (60000, 20)

# %% [markdown]
# #### A. Logistic Regression

# %%
lr = LogisticRegression(random_state=seed)
lr.fit(X_train_proj, y_train)
# Out:
# /home/kishore/Documents/Northeastern Coursework/USML/Code_Files/env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
y_train_pred = lr.predict(X_train_proj)

training_acc = accuracy_score(y_train, y_train_pred) * 100

print(f"Training Accuracy: {training_acc:.2f}%")
# Out:
# Training Accuracy: 87.46%

# %%
y_test_pred = lr.predict(X_test_proj)

testing_acc = accuracy_score(y_test, y_test_pred) * 100

print(f"Testing Accuracy: {testing_acc:.2f}%")
# Out:
# Testing Accuracy: 88.01%

# %% [markdown]
# #### B. Decision Tree Classifier

# %%
clf = DecisionTreeClassifier(random_state=seed)
clf.fit(X_train_proj, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_train_pred = clf.predict(X_train_proj)

training_acc = accuracy_score(y_train, y_train_pred) * 100

print(f"Training Accuracy: {training_acc:.2f}%")
# Out:
# Training Accuracy: 100.00%

# %%
y_test_pred = clf.predict(X_test_proj)

testing_acc = accuracy_score(y_test, y_test_pred) * 100

print(f"Testing Accuracy: {testing_acc:.2f}%")
# Out:
# Testing Accuracy: 84.89%
